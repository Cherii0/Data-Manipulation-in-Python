# %% [markdown]
# # Repairing/Fixing cols and rows
# * Data divided into multiple columns - Series.str.cat()
# * Multiple data in single column - Series.str.split()
# * Multiple data in single row label - .index.str.split()
# * Data divided into multiple rows - .index.str.cat()
# * Multiple observations in single cell - .assign().explode()
# * Columns labels contains data - pd.wide_to_long()

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(category=Warning, action="ignore")

# %%
fifa = pd.read_csv("../PROJECTS/FIFA/players_20.csv")

# %%
fifa.iloc[ : 3, 75:]
# Out:
#    goalkeeping_positioning  goalkeeping_reflexes  goalkeeping_speed    ls  \
# 0                       14                     8                NaN  89+5
# 1                       14                    11                NaN  91+2
# 2                       15                    11                NaN  84+6
#
#      st    rs    lw    lf    cf    rf  ...   lcb    cb   rcb    rb    gk  \
# 0  89+5  89+5  93+1  93+1  93+1  93+1  ...  53+6  53+6  53+6  63+6  19+6
# 1  91+2  91+2    90    91    91    91  ...  54+3  54+3  54+3  61+3  20+3
# 2  84+6  84+6  91+1  90+2  90+2  90+2  ...  47+6  47+6  47+6  61+6  20+6
#
#                                      player_face_url  \
# 0  https://cdn.sofifa.net/players/158/023/20_120.png
# 1  https://cdn.sofifa.net/players/020/801/20_120.png
# 2  https://cdn.sofifa.net/players/190/871/20_120.png
#
#                              club_logo_url  \
# 0  https://cdn.sofifa.net/teams/241/60.png
# 1   https://cdn.sofifa.net/teams/45/60.png
# 2   https://cdn.sofifa.net/teams/73/60.png
#
#                          club_flag_url  \
# 0  https://cdn.sofifa.net/flags/es.png
# 1  https://cdn.sofifa.net/flags/it.png
# 2  https://cdn.sofifa.net/flags/fr.png
#
#                             nation_logo_url  \
# 0                                       NaN
# 1  https://cdn.sofifa.net/teams/1354/60.png
# 2  https://cdn.sofifa.net/teams/1370/60.png
#
#                        nation_flag_url
# 0  https://cdn.sofifa.net/flags/ar.png
# 1  https://cdn.sofifa.net/flags/pt.png
# 2  https://cdn.sofifa.net/flags/br.png
#
# [3 rows x 35 columns]

# %% [markdown]
# # Multiple data in single column

# %%
pos = [col for col in list(fifa.columns) if "position" in col ]

# %%
fifa_pos = fifa[[pos[0]]]

# %%
fifa_pos.head(2)
# Out:
#   player_positions
# 0       RW, CF, ST
# 1           ST, LW

# %%
# option 1 - keep first occurence
fifa_pos["first"] = fifa_pos["player_positions"].str.split(pat = ", " ).str[0]

# %%
fifa_pos.head(3)
# Out:
#   player_positions first
# 0       RW, CF, ST    RW
# 1           ST, LW    ST
# 2          LW, CAM    LW

# %%
# option 2 - last occurence
fifa_pos["last"] = fifa_pos["player_positions"].str.split(pat = ", " ).str[-1]

# %%
fifa_pos.head(3)
# Out:
#   player_positions first last
# 0       RW, CF, ST    RW   ST
# 1           ST, LW    ST   LW
# 2          LW, CAM    LW  CAM

# %% [markdown]
# # Data divided into multiple cols

# %%
goalkeeping = [ col for col in list(fifa.columns) if "goalkeeping" in col]

# %%
goalkeeping
# Out:
# ['goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'goalkeeping_speed']

# %%
fifa.loc[:, goalkeeping[:-1]].isna().sum()
# Out:
# goalkeeping_diving         0
# goalkeeping_handling       0
# goalkeeping_kicking        0
# goalkeeping_positioning    0
# goalkeeping_reflexes       0
# dtype: int64

# %%
fifa_goalkeeping = fifa.loc[:, goalkeeping[:-1]]

# %%
fifa_goalkeeping.head(2)
# Out:
#    goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                   6                    11                   15
# 1                   7                    11                   15
#
#    goalkeeping_positioning  goalkeeping_reflexes
# 0                       14                     8
# 1                       14                    11

# %%
fifa_goalkeeping["stat_mean"] = fifa_goalkeeping.sum(axis = 1) / fifa_goalkeeping.shape[1]

# %%
fifa_names = fifa[["short_name", "long_name"]]

# %%
fifa_names.head(2)
# Out:
#           short_name                            long_name
# 0           L. Messi       Lionel Andrés Messi Cuccittini
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro

# %%
fifa_names["name"] = fifa["long_name"].str.split(pat = " ", n = 1).str[0]
fifa_names["surname"] = fifa["long_name"].str.split(pat = " ", n = 1).str[1]

# %%
fifa_names.head(2)
# Out:
#           short_name                            long_name       name  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini     Lionel
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  Cristiano
#
#                      surname
# 0    Andrés Messi Cuccittini
# 1  Ronaldo dos Santos Aveiro

# %%
fifa_names["full"] = fifa_names["name"].str.cat(fifa_names["surname"], sep = "-")

# %%
fifa_names.head()
# Out:
#           short_name                            long_name       name  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini     Lionel
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  Cristiano
# 2          Neymar Jr        Neymar da Silva Santos Júnior     Neymar
# 3          E. Hazard                          Eden Hazard       Eden
# 4       K. De Bruyne                      Kevin De Bruyne      Kevin
#
#                      surname                                 full
# 0    Andrés Messi Cuccittini       Lionel-Andrés Messi Cuccittini
# 1  Ronaldo dos Santos Aveiro  Cristiano-Ronaldo dos Santos Aveiro
# 2     da Silva Santos Júnior        Neymar-da Silva Santos Júnior
# 3                     Hazard                          Eden-Hazard
# 4                  De Bruyne                      Kevin-De Bruyne

# %% [markdown]
# # Multiple data in single row label

# %%
fifa_rows = fifa_names.loc[: , : ]

# %%
fifa_rows.set_index("full", inplace  = True)

# %%
fifa_rows.head(2)
# Out:
#                                             short_name  \
# full
# Lionel-Andrés Messi Cuccittini                L. Messi
# Cristiano-Ronaldo dos Santos Aveiro  Cristiano Ronaldo
#
#                                                                long_name  \
# full
# Lionel-Andrés Messi Cuccittini            Lionel Andrés Messi Cuccittini
# Cristiano-Ronaldo dos Santos Aveiro  Cristiano Ronaldo dos Santos Aveiro
#
#                                           name                    surname
# full
# Lionel-Andrés Messi Cuccittini          Lionel    Andrés Messi Cuccittini
# Cristiano-Ronaldo dos Santos Aveiro  Cristiano  Ronaldo dos Santos Aveiro

# %%
fifa_rows.index = fifa_rows.index.str.split("-", n = 1,  expand=True)

# %%
fifa_rows.index = fifa_rows.index.rename(["name", "surname2"])
fifa_rows.head(2)
# Out:
#                                             short_name  \
# name      surname2
# Lionel    Andrés Messi Cuccittini             L. Messi
# Cristiano Ronaldo dos Santos Aveiro  Cristiano Ronaldo
#
#                                                                long_name  \
# name      surname2
# Lionel    Andrés Messi Cuccittini         Lionel Andrés Messi Cuccittini
# Cristiano Ronaldo dos Santos Aveiro  Cristiano Ronaldo dos Santos Aveiro
#
#                                           name                    surname
# name      surname2
# Lionel    Andrés Messi Cuccittini       Lionel    Andrés Messi Cuccittini
# Cristiano Ronaldo dos Santos Aveiro  Cristiano  Ronaldo dos Santos Aveiro

# %% [markdown]
# #  Data divided in multi index

# %%
fifa_rows.head(2)
# Out:
#                                             short_name  \
# name      surname2
# Lionel    Andrés Messi Cuccittini             L. Messi
# Cristiano Ronaldo dos Santos Aveiro  Cristiano Ronaldo
#
#                                                                long_name  \
# name      surname2
# Lionel    Andrés Messi Cuccittini         Lionel Andrés Messi Cuccittini
# Cristiano Ronaldo dos Santos Aveiro  Cristiano Ronaldo dos Santos Aveiro
#
#                                           name                    surname
# name      surname2
# Lionel    Andrés Messi Cuccittini       Lionel    Andrés Messi Cuccittini
# Cristiano Ronaldo dos Santos Aveiro  Cristiano  Ronaldo dos Santos Aveiro

# %%
fifa_rows.reset_index(inplace=True, drop = False, level="surname2")

# %%
fifa_rows.head(2)
# Out:
#                             surname2         short_name  \
# name
# Lionel       Andrés Messi Cuccittini           L. Messi
# Cristiano  Ronaldo dos Santos Aveiro  Cristiano Ronaldo
#
#                                      long_name       name  \
# name
# Lionel          Lionel Andrés Messi Cuccittini     Lionel
# Cristiano  Cristiano Ronaldo dos Santos Aveiro  Cristiano
#
#                              surname
# name
# Lionel       Andrés Messi Cuccittini
# Cristiano  Ronaldo dos Santos Aveiro

# %%
fifa_rows.index = fifa_rows.index.str.cat(fifa_rows["surname2"], sep = "-")

# %%
fifa_rows.head(2)
# Out:
#                                                       surname2  \
# name
# Lionel-Andrés Messi Cuccittini         Andrés Messi Cuccittini
# Cristiano-Ronaldo dos Santos Aveiro  Ronaldo dos Santos Aveiro
#
#                                             short_name  \
# name
# Lionel-Andrés Messi Cuccittini                L. Messi
# Cristiano-Ronaldo dos Santos Aveiro  Cristiano Ronaldo
#
#                                                                long_name  \
# name
# Lionel-Andrés Messi Cuccittini            Lionel Andrés Messi Cuccittini
# Cristiano-Ronaldo dos Santos Aveiro  Cristiano Ronaldo dos Santos Aveiro
#
#                                           name                    surname
# name
# Lionel-Andrés Messi Cuccittini          Lionel    Andrés Messi Cuccittini
# Cristiano-Ronaldo dos Santos Aveiro  Cristiano  Ronaldo dos Santos Aveiro

# %% [markdown]
# # Multiple observation in single cell

# %%
fifa_obs = fifa.loc[:4 , ["short_name","st","rs", "lw",	"lf"]]

# %%
fifa_obs
# Out:
#           short_name    st    rs    lw    lf
# 0           L. Messi  89+5  89+5  93+1  93+1
# 1  Cristiano Ronaldo  91+2  91+2    90    91
# 2          Neymar Jr  84+6  84+6  91+1  90+2
# 3          E. Hazard  84+6  84+6  89+2  89+2
# 4       K. De Bruyne  83+3  83+3    87    87

# %%
fifa_obs.assign(st_points = fifa_obs["st"].str.split(pat = "+")).explode("st_points")
# Out:
#           short_name    st    rs    lw    lf st_points
# 0           L. Messi  89+5  89+5  93+1  93+1        89
# 0           L. Messi  89+5  89+5  93+1  93+1         5
# 1  Cristiano Ronaldo  91+2  91+2    90    91        91
# 1  Cristiano Ronaldo  91+2  91+2    90    91         2
# 2          Neymar Jr  84+6  84+6  91+1  90+2        84
# 2          Neymar Jr  84+6  84+6  91+1  90+2         6
# 3          E. Hazard  84+6  84+6  89+2  89+2        84
# 3          E. Hazard  84+6  84+6  89+2  89+2         6
# 4       K. De Bruyne  83+3  83+3    87    87        83
# 4       K. De Bruyne  83+3  83+3    87    87         3

# %% [markdown]
# # Columns labels contains data

# %%
attacking = [col for col in fifa.columns if "attacking" in col]
attacking.append("short_name")

# %%
attacking
# Out:
# ['attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys']

# %%
fifa_attacking = fifa.loc[:4 ,attacking[2:]]

# %%
fifa_attacking
# Out:
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       92                 88
# 1                          89                       83                 87
# 2                          62                       87                 87
# 3                          61                       89                 83
# 4                          55                       92                 82
#
#           short_name
# 0           L. Messi
# 1  Cristiano Ronaldo
# 2          Neymar Jr
# 3          E. Hazard
# 4       K. De Bruyne

# %%
pd.wide_to_long(
    df=fifa_attacking,
    i="short_name",
    stubnames=["attacking"],
    sep="_",
    j="attr",
    suffix="\w+"
).sort_index()
# Out:
#                                     attacking
# short_name        attr
# Cristiano Ronaldo heading_accuracy         89
#                   short_passing            83
#                   volleys                  87
# E. Hazard         heading_accuracy         61
#                   short_passing            89
#                   volleys                  83
# K. De Bruyne      heading_accuracy         55
#                   short_passing            92
#                   volleys                  82
# L. Messi          heading_accuracy         70
#                   short_passing            92
#                   volleys                  88
# Neymar Jr         heading_accuracy         62
#                   short_passing            87
#                   volleys                  87
